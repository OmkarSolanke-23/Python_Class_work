# %%
a = 10

print(type(a))

print(id(a))
# Out:
# <class 'int'>
# 4355961088

# %%
a = 10.6

print(type(a))

print(id(a))
# Out:
# <class 'float'>
# 4459043120

# %%
a = "omkar"

print(type(a))

print(id(a))
# Out:
# <class 'str'>
# 4449841248

# %%
s = "OmkarSolanke"

print(s[0])   
print(s[5])   

print(s[-1]) 
print(s[-7])  

print(s.index('S'))  

print(s[-2])  

print(s[5])   

print(s[3])   

print(s[8])   

print(s[len(s) - 1]) 

print(s[len(s) // 2])
# Out:
# O
# S
# e
# S
# 5
# k
# S
# a
# a
# e
# o

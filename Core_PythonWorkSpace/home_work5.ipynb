# %%
str = "omkar"

print(type(str))

print(id(str))
# Out:
# <class 'str'>
# 4495258272

# %%
num = float(input("enter the number : "))

print(type(num))

print(id(num))

# %%
a = 10
print(type(a))
print(id(a))
# Out:
# <class 'int'>
# 4358058240

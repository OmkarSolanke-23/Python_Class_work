# %%
num = 20
print(type(num))

print(id(num))
# Out:
# <class 'int'>
# 4365775424

# %%
str = "omkar"

print(type(str))

print(id(str))

# %%
num = True

print(type(num))

print(id(num))
# Out:
# <class 'bool'>
# 4365761016

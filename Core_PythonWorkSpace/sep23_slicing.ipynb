# %%
s = "Data Analysis"

print(s[:])
print(s[0:4])
print(s[5:13])
print(s[:4])
print(s[5:])
print(s[::1])
print(s[::2])
print(s[::3])
print(s[1:8])
print(s[2:10])
print(s[0:13:2])
print(s[1:13:2])
print(s[-8:])
print(s[:-9])
print(s[-8:-1])
print(s[5:12])
print(s[::-1])
print(s[12:4:-1])
print(s[-1:-8:-1])
print(s[::2])
# Out:
# Data Analysis
# Data
# Analysis
# Data
# Analysis
# Data Analysis
# Dt nlss
# Danys
# ata Ana
# ta Analy
# Dt nlss
# aaAayi
# Analysis
# Data
# Analysi
# Analysi
# sisylanA ataD
# sisylanA
# sisylan
# Dt nlss

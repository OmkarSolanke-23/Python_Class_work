# %%
str = "omkar"

print(type(str))

print(id(str))
# Out:
# <class 'str'>
# 4474489472

# %%
str = True

print(type(str))

print(id(str))
# Out:
# <class 'bool'>
# 4367809016

# %%
num = 89.00000

print(type(num))

print(id(num))
# Out:
# <class 'float'>
# 4466662000

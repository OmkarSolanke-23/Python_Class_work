# %%
a = 11
print(a)
print(type(a))

# %%
a = 10.00 + 20j

                            

print(a)
print(type(a))

# %%
name = input("name")
print(name)

# %%
a  = int(input("age"))

print(a)
print(type(a))

# %%
a  = int(input("num1 "))
b = complex(input("num2 "))

c = a + b

print(c)

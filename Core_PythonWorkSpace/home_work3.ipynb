# %%
str = "omkar"
print(type(str))

print(id(str))
# Out:
# home work 3

# %%
num = "10"

print(type(num))

print(id(num))
# Out:
# <class 'str'>
# 4310048832

# %%
num = 60

print(type(num))

print(id(num))
# Out:
# <class 'int'>
# 4317345600
